# %%
from func_plot import *

# %%
df=pd.read_csv(r"creditcard.csv")

# %%
'''df.rename(columns={"Diabetes_012": "Diabetes"}, inplace=True)


df.drop(df[df['Diabetes'] == 1].index, inplace=True)

map = {
    0: 0,
    2: 1,
    
}
df["Diabetes"] = df["Diabetes"].replace(map)'''

# %%
numeric_columns=get_numeric_columns(df)
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
make_boxplot(numeric_columns,'Class',df)
# Out:
# c:\Users\karol\Desktop\machine_learning\licnecnjat\func_plot.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i)

# %%
make_violinplot(numeric_columns,'Class',df)
# Out:
# c:\Users\karol\Desktop\machine_learning\licnecnjat\func_plot.py:32: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i)

# %%
swarm_cols=['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate','EmployeeNumber']

make_swarmplot(numeric_columns,'Diabetes',df.sample(1000))
# Out:
# c:\Users\karol\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 81.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\karol\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 63.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\karol\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 63.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\karol\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 77.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...
